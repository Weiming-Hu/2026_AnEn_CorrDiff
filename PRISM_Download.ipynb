# %%
import pandas as pd

from tqdm.auto import tqdm
from utils.download import touch_prism

# %%
for dt in tqdm(pd.date_range('2019-01-01', '2024-12-31', freq='d')):
    touch_prism(dt, variable='ppt')
    touch_prism(dt, variable='tmean')
# Out:
#   0%|          | 0/2192 [00:00<?, ?it/s]

# %%
print('Done!')
# Out:
# Done!
